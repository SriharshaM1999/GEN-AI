# %%
# !pip install langchain langchain-core langchain-community pydantic duckduckgo-search langchain_experimental ddgs
# Out:
# Requirement already satisfied: langchain in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (1.3.1)
# Requirement already satisfied: langchain-core in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (1.4.0)
# Requirement already satisfied: langchain-community in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (0.4.2)
# Requirement already satisfied: pydantic in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (2.13.4)
# Requirement already satisfied: duckduckgo-search in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (8.1.1)
# Requirement already satisfied: langchain_experimental in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (0.4.2)
# Requirement already satisfied: ddgs in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (9.14.4)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain) (1.2.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-core) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-core) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (0.3.15)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (4.13.0)
# Requirement already satisfied: certifi in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.16)
# Requirement already satisfied: h11>=0.16 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-community) (3.14.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: numpy>=2.1.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-community) (2.0.50)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Requirement already satisfied: click>=8.1.8 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from duckduckgo-search) (8.4.1)
# Requirement already satisfied: primp>=0.15.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from duckduckgo-search) (1.3.1)
# Requirement already satisfied: lxml>=5.3.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from duckduckgo-search) (6.1.1)
# Requirement already satisfied: fake-useragent>=2.2.0 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from ddgs) (2.2.0)
# Requirement already satisfied: brotli in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.4.0)
# Requirement already satisfied: socksio==1.* in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.2 in /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.2.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
#### WEB SEARCH TOOL

from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.output_parsers import StrOutputParser
# tool
search_tool = DuckDuckGoSearchRun()

# outputParser
strOutputParser = StrOutputParser()

chain = search_tool | strOutputParser

result = chain.invoke("what is your source")

print(result)
# Out:
# May 18, 2020 · I’ve realized that throughout my life when I have felt any form of insecurity or anxiety, it is always when I have forgotten what—or rather Who—the source of perfect security and peace in my life is: Jesus. Apr 15, 2026 · Merriam-Webster defines a source as: "1. someone or something that provides what is wanted or needed; 2. the cause of something (such as a problem); 3. a person, book, etc., that gives information" Oct 2, 2019 · But, (and this is critical) can your source be unexpected, even miraculous? Or would you reject the unexpected because it simply made no sense? Fulfillment from unexpected sources requires... Jun 4, 2023 · Learn how to find and evaluate online sources. Students will explore what makes information reliable and useful. This lesson is part of MiaPrep’s High School... Nov 20, 2024 · Part of our Roll Tide Research series on "Identifying Sources", this video will explain what types of information can be considered as sources when researching. Access the video transcript... Oct 15, 2024 · Identity drives more of your life’s journey than you may realize. The source of your identity will lead you down one of two completely different paths: one leading to unexpected despair, the other leading to ultimate freedom. Jul 9, 2018 · Learn how to fully rely on God for every need and desire with these 70 scriptures that prove God is your Source! God is your Source! Sound easier to say than believe? When it comes to standing in faith for things we know we need to survive or want so desperately, the battle is on. Nov 20, 2024 · Part of our Roll Tide Research series on "Identifying Sources", this video will explain what types of information can be considered as sources when researching. Access the video transcript... Oct 15, 2024 · Identity drives more of your life’s journey than you may realize. The source of your identity will lead you down one of two completely different paths: one leading to unexpected despair, the other leading to ultimate freedom. Jul 9, 2018 · Learn how to fully rely on God for every need and desire with these 70 scriptures that prove God is your Source! God is your Source! Sound easier to say than believe? When it comes to standing in faith for things we know we need to survive or want so desperately, the battle is on.

# %%
#### SHELL TOOL

from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('whoami')

print(results)
# Out:
# Executing command:
#  whoami
# sriharshamadireddy
# /Users/sriharshamadireddy/Desktop/Personal/Learning/DataScience/genai/venv/lib/python3.13/site-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
